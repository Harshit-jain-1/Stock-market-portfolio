# %% [markdown]
# <a href="https://colab.research.google.com/github/Harshit-jain-1/Stock-market-portfolio/blob/main/AI_agent_with_agentic_AI_for_stock.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# import library
import yfinance as yf
import pandas as pd
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
import random
from collections import deque

# %%
# define stock symbol and time period
symbol = "GOOG"
start_date = "2020-01-01"
end_date = "2025-03-01"

# download historical data
data = yf.download(symbol, start=start_date, end=end_date)
# Out:
# YF.download() has changed argument auto_adjust default to True
# [*********************100%***********************]  1 of 1 completed

# %%
# feature engineering
data['SMA_5'] = data['Close'].rolling(window=5).mean()
data['SMA_20'] = data['Close'].rolling(window=20).mean()
data['Returns'] = data['Close'].pct_change()

# %%
# drop NaN values and reset index
data.dropna(inplace=True)
data.reset_index(drop=True, inplace=True)

# %%
# define action space
ACTIONS = {0: "HOLD", 1: "BUY", 2: "SELL"}

# %%
# get state function
def get_state(data, index):
    return np.array([
        float(data.loc[index, 'Close']),
        float(data.loc[index, 'SMA_5']),
        float(data.loc[index, 'SMA_20']),
        float(data.loc[index, 'Returns'])
    ])

# %%
# trading environment
class TradingEnvironment:
    def __init__(self, data):
        self.data = data # The historical stock data (e.g., closing prices, moving averages, etc.)
        self.initial_balance = 10000 # Starting balance in dollars
        self.balance = self.initial_balance # Current balance (starts with the initial balance)
        self.holdings = 0 # Amount of stock held (starts with 0)
        self.index = 0 # The current index (position in the data)

    def reset(self):
        self.balance = self.initial_balance # Reset balance to the initial value
        self.holdings = 0 # Reset holdings to 0 (agent is not holding any stock)
        self.index = 0 # Reset the index to the first data point
        return get_state(self.data, self.index) # Return the initial state

    def step(self, action):
        price = float(self.data.loc[self.index, 'Close']) # Get the current price (closing price)
        reward = 0 # Initialize reward to 0

        # Perform the action: BUY (1) or SELL (2)
        if action == 1 and self.balance >= price:  # BUY
            self.holdings = self.balance // price # Calculate how many shares can be bought
            self.balance -= self.holdings * price # Subtract the cost of the shares from the balance
        elif action == 2 and self.holdings > 0:  # SELL
            self.balance += self.holdings * price # Add the revenue from selling the shares to the balance
            self.holdings = 0 # Reset holdings to 0 after selling

        self.index += 1 # Move to the next day in the data
        done = self.index >= len(self.data) - 1 # Check if the simulation is complete (end of data)

        if done:
            reward = self.balance - self.initial_balance # Reward is the profit/loss

        next_state = get_state(self.data, self.index) if not done else None
        return next_state, reward, done, {}

# %%
# deep q-network
class DQN(nn.Module):
    def __init__(self, state_size, action_size):
        super(DQN, self).__init__()
        self.fc1 = nn.Linear(state_size, 64)  # First fully connected layer
        self.fc2 = nn.Linear(64, 64)  # Second fully connected layer
        self.fc3 = nn.Linear(64, action_size)  # Output layer

    def forward(self, x):
        x = torch.relu(self.fc1(x))  # Apply ReLU activation to the first layer
        x = torch.relu(self.fc2(x))  # Apply ReLU activation to the second layer
        return self.fc3(x)  # Output layer returns the Q-values

# %%
# DQN agent
class DQNAgent:
    def __init__(self, state_size, action_size):
        self.state_size = state_size
        self.action_size = action_size
        self.memory = deque(maxlen=2000) # Memory buffer with max size of 2000
        self.gamma = 0.95  # Discount factor
        self.epsilon = 1.0  # Exploration rate
        self.epsilon_min = 0.01 # Minimum value for epsilon (exploration)
        self.epsilon_decay = 0.995 # Decay rate for epsilon
        self.learning_rate = 0.001 # Learning rate for model optimization
        self.model = DQN(state_size, action_size) # The DQN model (Q-network)
        self.optimizer = optim.Adam(self.model.parameters(), lr=self.learning_rate)
        self.criterion = nn.MSELoss()

    def remember(self, state, action, reward, next_state, done):
        self.memory.append((state, action, reward, next_state, done))

    def act(self, state):
        if random.uniform(0, 1) < self.epsilon:
          return random.choice(list(ACTIONS.keys()))  # Exploration: random action
        state = torch.FloatTensor(state).unsqueeze(0)  # Convert state to tensor and add batch dimension
        with torch.no_grad():
          q_values = self.model(state)  # Predict Q-values for each action
        return torch.argmax(q_values).item()  # Exploitation: return the action with the highest Q-value

    def replay(self, batch_size):
        if len(self.memory) < batch_size:
            return
        minibatch = random.sample(self.memory, batch_size)

        for state, action, reward, next_state, done in minibatch:
            target = reward
            if not done:
                next_state_tensor = torch.FloatTensor(next_state).unsqueeze(0)
                target += self.gamma * torch.max(self.model(next_state_tensor)).item()

            state_tensor = torch.FloatTensor(state).unsqueeze(0) # Convert state to tensor
            target_tensor = self.model(state_tensor).clone().detach()  # Clone model's Q-values
            target_tensor[0][action] = target  # Update the target for the specific action

            self.optimizer.zero_grad()  # Zero the gradients of the model
            output = self.model(state_tensor)  # Get the current Q-values for the state
            loss = self.criterion(output, target_tensor)  # Calculate the loss (MSE between Q-values)
            loss.backward()  # Backpropagate the loss
            self.optimizer.step()  # Update the model's parameters

        if self.epsilon > self.epsilon_min:
            self.epsilon *= self.epsilon_decay

# %%
# train the agent
env = TradingEnvironment(data)
agent = DQNAgent(state_size=4, action_size=3)
batch_size = 32
episodes = 1000
total_rewards = []

for episode in range(episodes):
    state = env.reset()
    done = False
    total_reward = 0

    while not done:
        action = agent.act(state)
        next_state, reward, done, _ = env.step(action)
        agent.remember(state, action, reward, next_state, done)
        state = next_state
        total_reward += reward

    agent.replay(batch_size)
    total_rewards.append(total_reward)
    print(f"Episode {episode+1}/{episodes}, Total Reward: {total_reward}")

print("Training Complete!")
# Out:
# <ipython-input-6-3915787d8dfc>:4: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   float(data.loc[index, 'Close']),
# <ipython-input-6-3915787d8dfc>:5: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   float(data.loc[index, 'SMA_5']),
# <ipython-input-6-3915787d8dfc>:6: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   float(data.loc[index, 'SMA_20']),
# <ipython-input-6-3915787d8dfc>:7: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   float(data.loc[index, 'Returns'])
# <ipython-input-7-47ae0b5c48ca>:17: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   price = float(self.data.loc[self.index, 'Close']) # Get the current price (closing price)
# Episode 1/1000, Total Reward: -9987.103031158447
# Episode 2/1000, Total Reward: -9914.385829925537
# Episode 3/1000, Total Reward: -9898.291049957275
# Episode 4/1000, Total Reward: -9903.004447937012
# Episode 5/1000, Total Reward: -9914.729091644287
# Episode 6/1000, Total Reward: -9881.305938720703
# Episode 7/1000, Total Reward: -9902.10478591919
# Episode 8/1000, Total Reward: -9884.3890914917
# Episode 9/1000, Total Reward: -9794.944774627686
# Episode 10/1000, Total Reward: -9909.824466705322
# Episode 11/1000, Total Reward: -9887.926235198975
# Episode 12/1000, Total Reward: -9885.515453338623
# Episode 13/1000, Total Reward: -9903.89836883545
# Episode 14/1000, Total Reward: -9768.748672485352
# Episode 15/1000, Total Reward: -9897.36173248291
# Episode 16/1000, Total Reward: -9994.958473205566
# Episode 17/1000, Total Reward: -9934.299583435059
# Episode 18/1000, Total Reward: -9933.639183044434
# Episode 19/1000, Total Reward: -9870.354633331299
# Episode 20/1000, Total Reward: -9980.978504180908
# Episode 21/1000, Total Reward: -9842.731369018555
# Episode 22/1000, Total Reward: -9888.028968811035
# Episode 23/1000, Total Reward: -9919.390342712402
# Episode 24/1000, Total Reward: -9813.802448272705
# Episode 25/1000, Total Reward: -9912.022144317627
# Episode 26/1000, Total Reward: -9902.588111877441
# Episode 27/1000, Total Reward: -9840.72554397583
# Episode 28/1000, Total Reward: -9904.767288208008
# Episode 29/1000, Total Reward: -9876.095531463623
# Episode 30/1000, Total Reward: 18657.354026794434
# Episode 31/1000, Total Reward: -9891.364418029785
# Episode 32/1000, Total Reward: -9924.31776046753
# Episode 33/1000, Total Reward: -9831.80209350586
# Episode 34/1000, Total Reward: -9996.71981048584
# Episode 35/1000, Total Reward: -9902.948860168457
# Episode 36/1000, Total Reward: -9892.422218322754
# Episode 37/1000, Total Reward: -9851.066097259521
# Episode 38/1000, Total Reward: -9924.993049621582
# Episode 39/1000, Total Reward: -9899.842617034912
# Episode 40/1000, Total Reward: -9924.155643463135
# Episode 41/1000, Total Reward: -9924.352657318115
# Episode 42/1000, Total Reward: -9875.17147064209
# Episode 43/1000, Total Reward: -9901.98152923584
# Episode 44/1000, Total Reward: -9858.547985076904
# Episode 45/1000, Total Reward: -9807.619430541992
# Episode 46/1000, Total Reward: -9898.988342285156
# Episode 47/1000, Total Reward: -9876.370189666748
# Episode 48/1000, Total Reward: -9909.925201416016
# Episode 49/1000, Total Reward: -9943.472839355469
# Episode 50/1000, Total Reward: -9903.403385162354
# Episode 51/1000, Total Reward: -9911.148502349854
# Episode 52/1000, Total Reward: -9917.555225372314
# Episode 53/1000, Total Reward: -9945.503192901611
# Episode 54/1000, Total Reward: -9878.724220275879
# Episode 55/1000, Total Reward: -9880.575634002686
# Episode 56/1000, Total Reward: -9920.698402404785
# Episode 57/1000, Total Reward: -9841.72566986084
# Episode 58/1000, Total Reward: -9893.316722869873
# Episode 59/1000, Total Reward: -9989.64448928833
# Episode 60/1000, Total Reward: -9890.66003036499
# Episode 61/1000, Total Reward: -9848.111087799072
# Episode 62/1000, Total Reward: -9883.607650756836
# Episode 63/1000, Total Reward: -9900.125171661377
# Episode 64/1000, Total Reward: -9874.950508117676
# Episode 65/1000, Total Reward: -9911.07568359375
# Episode 66/1000, Total Reward: -9823.578338623047
# Episode 67/1000, Total Reward: -9965.209381103516
# Episode 68/1000, Total Reward: -9867.259754180908
# Episode 69/1000, Total Reward: -9913.824996948242
# Episode 70/1000, Total Reward: -9944.589199066162
# Episode 71/1000, Total Reward: -487.96894454956055
# Episode 72/1000, Total Reward: -9887.50724029541
# Episode 73/1000, Total Reward: -9971.15571975708
# Episode 74/1000, Total Reward: -9762.79192352295
# Episode 75/1000, Total Reward: -9992.653255462646
# Episode 76/1000, Total Reward: -9908.27311706543
# Episode 77/1000, Total Reward: -9837.427604675293
# Episode 78/1000, Total Reward: -9929.607513427734
# Episode 79/1000, Total Reward: -9899.935066223145
# Episode 80/1000, Total Reward: -9860.270004272461
# Episode 81/1000, Total Reward: -9936.595554351807
# Episode 82/1000, Total Reward: -9906.26724243164
# Episode 83/1000, Total Reward: -9884.968322753906
# Episode 84/1000, Total Reward: 17540.293060302734
# Episode 85/1000, Total Reward: 3952.7847633361816
# Episode 86/1000, Total Reward: -9916.386989593506
# Episode 87/1000, Total Reward: -9928.905364990234
# Episode 88/1000, Total Reward: -9936.888023376465
# Episode 89/1000, Total Reward: -9946.761192321777
# Episode 90/1000, Total Reward: -9893.502952575684
# Episode 91/1000, Total Reward: -9787.400680541992
# Episode 92/1000, Total Reward: -9926.357963562012
# Episode 93/1000, Total Reward: -9943.496395111084
# Episode 94/1000, Total Reward: -9871.29902267456
# Episode 95/1000, Total Reward: -9912.755531311035
# Episode 96/1000, Total Reward: -9937.549053192139
# Episode 97/1000, Total Reward: -9926.76245880127
# Episode 98/1000, Total Reward: -9914.633731842041
# Episode 99/1000, Total Reward: -9929.023654937744
# Episode 100/1000, Total Reward: -9948.145069122314
# Episode 101/1000, Total Reward: -9872.527439117432
# Episode 102/1000, Total Reward: -9991.471111297607
# Episode 103/1000, Total Reward: -9934.675350189209
# Episode 104/1000, Total Reward: -9932.071166992188
# Episode 105/1000, Total Reward: -9896.54454421997
# Episode 106/1000, Total Reward: -9886.365200042725
# Episode 107/1000, Total Reward: -9922.600551605225
# Episode 108/1000, Total Reward: -9931.609062194824
# Episode 109/1000, Total Reward: -9993.9839553833
# Episode 110/1000, Total Reward: -9805.245918273926
# Episode 111/1000, Total Reward: -9793.557888031006
# Episode 112/1000, Total Reward: -9795.870399475098
# Episode 113/1000, Total Reward: 6670.31649017334
# Episode 114/1000, Total Reward: -9825.427196502686
# Episode 115/1000, Total Reward: -9895.811672210693
# Episode 116/1000, Total Reward: -9845.603614807129
# Episode 117/1000, Total Reward: -9868.519355773926
# Episode 118/1000, Total Reward: -9906.095371246338
# Episode 119/1000, Total Reward: -9998.82462310791
# Episode 120/1000, Total Reward: -9920.860473632812
# Episode 121/1000, Total Reward: -9869.76798248291
# Episode 122/1000, Total Reward: -9850.346408843994
# Episode 123/1000, Total Reward: -9847.003894805908
# Episode 124/1000, Total Reward: -9927.106948852539
# Episode 125/1000, Total Reward: -9886.701641082764
# Episode 126/1000, Total Reward: -9792.132991790771
# Episode 127/1000, Total Reward: -9895.378746032715
# Episode 128/1000, Total Reward: -9838.125679016113
# Episode 129/1000, Total Reward: -9802.512512207031
# Episode 130/1000, Total Reward: -9999.554672241211
# Episode 131/1000, Total Reward: -9909.424961090088
# Episode 132/1000, Total Reward: -9830.068374633789
# Episode 133/1000, Total Reward: -9996.519947052002
# Episode 134/1000, Total Reward: -9999.52753829956
# Episode 135/1000, Total Reward: -9825.403186798096
# Episode 136/1000, Total Reward: -9891.851707458496
# Episode 137/1000, Total Reward: -9921.11527633667
# Episode 138/1000, Total Reward: -9997.658382415771
# Episode 139/1000, Total Reward: -9852.247932434082
# Episode 140/1000, Total Reward: -9952.102924346924
# Episode 141/1000, Total Reward: -9861.086296081543
# Episode 142/1000, Total Reward: -9889.142719268799
# Episode 143/1000, Total Reward: -9937.67180633545
# Episode 144/1000, Total Reward: -9852.419418334961
# Episode 145/1000, Total Reward: -9920.074485778809
# Episode 146/1000, Total Reward: -9904.844848632812
# Episode 147/1000, Total Reward: -9998.514583587646
# Episode 148/1000, Total Reward: -9916.560340881348
# Episode 149/1000, Total Reward: -9996.055183410645
# Episode 150/1000, Total Reward: -9899.139514923096
# Episode 151/1000, Total Reward: -9910.237464904785
# Episode 152/1000, Total Reward: -9882.949081420898
# Episode 153/1000, Total Reward: -9907.598861694336
# Episode 154/1000, Total Reward: -9893.288970947266
# Episode 155/1000, Total Reward: -9910.97529220581
# Episode 156/1000, Total Reward: -9931.977760314941
# Episode 157/1000, Total Reward: -9927.735973358154
# Episode 158/1000, Total Reward: -9827.485675811768
# Episode 159/1000, Total Reward: -9888.054363250732
# Episode 160/1000, Total Reward: -9905.099838256836
# Episode 161/1000, Total Reward: -9910.630798339844
# Episode 162/1000, Total Reward: -9823.62585067749
# Episode 163/1000, Total Reward: -9992.619659423828
# Episode 164/1000, Total Reward: -9973.452980041504
# Episode 165/1000, Total Reward: -9909.327785491943
# Episode 166/1000, Total Reward: -9842.524284362793
# Episode 167/1000, Total Reward: -9885.314037322998
# Episode 168/1000, Total Reward: -9886.196548461914
# Episode 169/1000, Total Reward: -9878.688972473145
# Episode 170/1000, Total Reward: -9983.762619018555
# Episode 171/1000, Total Reward: -9892.838851928711
# Episode 172/1000, Total Reward: -9998.650245666504
# Episode 173/1000, Total Reward: -9936.035190582275
# Episode 174/1000, Total Reward: -9984.2240524292
# Episode 175/1000, Total Reward: -9965.59188079834
# Episode 176/1000, Total Reward: -9883.31286239624
# Episode 177/1000, Total Reward: -9938.031311035156
# Episode 178/1000, Total Reward: -9921.317886352539
# Episode 179/1000, Total Reward: -9938.229106903076
# Episode 180/1000, Total Reward: -9935.52723312378
# Episode 181/1000, Total Reward: -9969.877220153809
# Episode 182/1000, Total Reward: -9839.077861785889
# Episode 183/1000, Total Reward: -9990.161724090576
# Episode 184/1000, Total Reward: -9813.379192352295
# Episode 185/1000, Total Reward: -9964.125652313232
# Episode 186/1000, Total Reward: -9917.201755523682
# Episode 187/1000, Total Reward: -9905.334274291992
# Episode 188/1000, Total Reward: -9886.024890899658
# Episode 189/1000, Total Reward: -9857.041275024414
# Episode 190/1000, Total Reward: -9999.27364730835
# Episode 191/1000, Total Reward: -9868.6438331604
# Episode 192/1000, Total Reward: -9752.586204528809
# Episode 193/1000, Total Reward: -9862.116092681885
# Episode 194/1000, Total Reward: -9842.169570922852
# Episode 195/1000, Total Reward: -9920.234676361084
# Episode 196/1000, Total Reward: -9905.88833618164
# Episode 197/1000, Total Reward: -9999.736274719238
# Episode 198/1000, Total Reward: -9830.430389404297
# Episode 199/1000, Total Reward: -9946.24118423462
# Episode 200/1000, Total Reward: -9919.826881408691
# Episode 201/1000, Total Reward: -9874.460647583008
# Episode 202/1000, Total Reward: -9900.306159973145
# Episode 203/1000, Total Reward: -9851.02018737793
# Episode 204/1000, Total Reward: -9908.476318359375
# Episode 205/1000, Total Reward: -9997.890274047852
# Episode 206/1000, Total Reward: -9974.52670288086
# Episode 207/1000, Total Reward: -1825.1139221191406
# Episode 208/1000, Total Reward: -1008.6078262329102
# Episode 209/1000, Total Reward: 790.3896636962891
# Episode 210/1000, Total Reward: 3806.519630432129
# Episode 211/1000, Total Reward: 2247.4617500305176
# Episode 212/1000, Total Reward: -9918.93632888794
# Episode 213/1000, Total Reward: 4146.273330688477
# Episode 214/1000, Total Reward: -9943.382724761963
# Episode 215/1000, Total Reward: -9928.113765716553
# Episode 216/1000, Total Reward: 10243.791946411133
# Episode 217/1000, Total Reward: 14347.998069763184
# Episode 218/1000, Total Reward: -9909.969924926758
# Episode 219/1000, Total Reward: 4766.236946105957
# Episode 220/1000, Total Reward: -9828.621131896973
# Episode 221/1000, Total Reward: -9871.870544433594
# Episode 222/1000, Total Reward: 1196.3897247314453
# Episode 223/1000, Total Reward: -9923.934871673584
# Episode 224/1000, Total Reward: -2028.202091217041
# Episode 225/1000, Total Reward: -9875.381607055664
# Episode 226/1000, Total Reward: 5664.875988006592
# Episode 227/1000, Total Reward: 2072.058624267578
# Episode 228/1000, Total Reward: -9877.598907470703
# Episode 229/1000, Total Reward: 1763.671989440918
# Episode 230/1000, Total Reward: -9885.754356384277
# Episode 231/1000, Total Reward: 2524.2511863708496
# Episode 232/1000, Total Reward: 5174.583278656006
# Episode 233/1000, Total Reward: 2636.1980323791504
# Episode 234/1000, Total Reward: -9843.831031799316
# Episode 235/1000, Total Reward: -1476.1528129577637
# Episode 236/1000, Total Reward: -4255.759666442871
# Episode 237/1000, Total Reward: 3015.3252487182617
# Episode 238/1000, Total Reward: -929.9061889648438
# Episode 239/1000, Total Reward: -9878.55591583252
# Episode 240/1000, Total Reward: -3066.5897331237793
# Episode 241/1000, Total Reward: 87.56603240966797
# Episode 242/1000, Total Reward: 4871.373886108398
# Episode 243/1000, Total Reward: -46.333778381347656
# Episode 244/1000, Total Reward: -1677.4796867370605
# Episode 245/1000, Total Reward: -9938.250793457031
# Episode 246/1000, Total Reward: 7211.632129669189
# Episode 247/1000, Total Reward: -9995.448417663574
# Episode 248/1000, Total Reward: -9856.11315536499
# Episode 249/1000, Total Reward: 2692.0676803588867
# Episode 250/1000, Total Reward: 3404.832275390625
# Episode 251/1000, Total Reward: 4580.425331115723
# Episode 252/1000, Total Reward: -9893.544208526611
# Episode 253/1000, Total Reward: -9924.80415725708
# Episode 254/1000, Total Reward: -9847.60831451416
# Episode 255/1000, Total Reward: -9832.900539398193
# Episode 256/1000, Total Reward: 3757.3712730407715
# Episode 257/1000, Total Reward: -776.824390411377
# Episode 258/1000, Total Reward: -9905.414443969727
# Episode 259/1000, Total Reward: 6999.456287384033
# Episode 260/1000, Total Reward: -652.1437034606934
# Episode 261/1000, Total Reward: -9920.038208007812
# Episode 262/1000, Total Reward: 2385.2594261169434
# Episode 263/1000, Total Reward: 1272.6020317077637
# Episode 264/1000, Total Reward: -2456.9231300354004
# Episode 265/1000, Total Reward: -9968.905464172363
# Episode 266/1000, Total Reward: -9878.135536193848
# Episode 267/1000, Total Reward: -1806.2471923828125
# Episode 268/1000, Total Reward: 1239.1105422973633
# Episode 269/1000, Total Reward: -9883.643730163574
# Episode 270/1000, Total Reward: -9917.12350845337
# Episode 271/1000, Total Reward: -9909.331909179688
# Episode 272/1000, Total Reward: 5787.754417419434
# Episode 273/1000, Total Reward: -9993.580490112305
# Episode 274/1000, Total Reward: -9957.713066101074
# Episode 275/1000, Total Reward: 4711.641689300537
# Episode 276/1000, Total Reward: 3241.1297492980957
# Episode 277/1000, Total Reward: -9851.00984954834
# Episode 278/1000, Total Reward: 3230.5697174072266
# Episode 279/1000, Total Reward: -9867.387046813965
# Episode 280/1000, Total Reward: 2759.8545303344727
# Episode 281/1000, Total Reward: -9977.129177093506
# Episode 282/1000, Total Reward: -9984.206642150879
# Episode 283/1000, Total Reward: -9965.732891082764
# Episode 284/1000, Total Reward: -9981.858058929443
# Episode 285/1000, Total Reward: -9952.94666671753
# Episode 286/1000, Total Reward: -9959.178787231445
# Episode 287/1000, Total Reward: -9932.856410980225
# Episode 288/1000, Total Reward: -9985.848106384277
# Episode 289/1000, Total Reward: -9866.468196868896
# Episode 290/1000, Total Reward: -9923.261283874512
# Episode 291/1000, Total Reward: 5982.955898284912
# Episode 292/1000, Total Reward: -9850.963592529297
# Episode 293/1000, Total Reward: -9875.770202636719
# Episode 294/1000, Total Reward: 4225.842807769775
# Episode 295/1000, Total Reward: -9969.458129882812
# Episode 296/1000, Total Reward: -9877.243492126465
# Episode 297/1000, Total Reward: 8592.791915893555
# Episode 298/1000, Total Reward: -9908.223628997803
# Episode 299/1000, Total Reward: -9972.571678161621
# Episode 300/1000, Total Reward: 4329.397399902344
# Episode 301/1000, Total Reward: -9901.859729766846
# Episode 302/1000, Total Reward: -9895.8948097229
# Episode 303/1000, Total Reward: 9660.182453155518
# Episode 304/1000, Total Reward: -9896.894119262695
# Episode 305/1000, Total Reward: -9926.196147918701
# Episode 306/1000, Total Reward: 8799.0669631958
# Episode 307/1000, Total Reward: -9865.088890075684
# Episode 308/1000, Total Reward: -9838.601203918457
# Episode 309/1000, Total Reward: -9871.515113830566
# Episode 310/1000, Total Reward: 5075.901962280273
# Episode 311/1000, Total Reward: 12311.417232513428
# Episode 312/1000, Total Reward: 2574.2809982299805
# Episode 313/1000, Total Reward: -9890.090675354004
# Episode 314/1000, Total Reward: 4979.684059143066
# Episode 315/1000, Total Reward: -9895.762596130371
# Episode 316/1000, Total Reward: 12456.957382202148
# Episode 317/1000, Total Reward: 6996.566368103027
# Episode 318/1000, Total Reward: -9925.620780944824
# Episode 319/1000, Total Reward: 5134.585105895996
# Episode 320/1000, Total Reward: -9967.03840637207
# Episode 321/1000, Total Reward: -9934.683418273926
# Episode 322/1000, Total Reward: 13484.423847198486
# Episode 323/1000, Total Reward: -9853.947738647461
# Episode 324/1000, Total Reward: -9906.423240661621
# Episode 325/1000, Total Reward: -9975.197059631348
# Episode 326/1000, Total Reward: 15714.395076751709
# Episode 327/1000, Total Reward: 28543.575859069824
# Episode 328/1000, Total Reward: -9952.16381072998
# Episode 329/1000, Total Reward: -9813.738231658936
# Episode 330/1000, Total Reward: -9953.54067993164
# Episode 331/1000, Total Reward: -9963.339282989502
# Episode 332/1000, Total Reward: -9860.762615203857
# Episode 333/1000, Total Reward: 14704.14949798584
# Episode 334/1000, Total Reward: -9929.392517089844
# Episode 335/1000, Total Reward: -9909.421142578125
# Episode 336/1000, Total Reward: -9929.025062561035
# Episode 337/1000, Total Reward: 21504.567413330078
# Episode 338/1000, Total Reward: -9848.923679351807
# Episode 339/1000, Total Reward: -9986.389511108398
# Episode 340/1000, Total Reward: -9931.647201538086
# Episode 341/1000, Total Reward: -9844.248794555664
# Episode 342/1000, Total Reward: -9984.26208114624
# Episode 343/1000, Total Reward: -9869.435157775879
# Episode 344/1000, Total Reward: 18750.637855529785
# Episode 345/1000, Total Reward: -1888.0721130371094
# Episode 346/1000, Total Reward: -9945.073162078857
# Episode 347/1000, Total Reward: -9903.069736480713
# Episode 348/1000, Total Reward: -9842.112182617188
# Episode 349/1000, Total Reward: -9998.15323638916
# Episode 350/1000, Total Reward: -9863.311031341553
# Episode 351/1000, Total Reward: -9836.533111572266
# Episode 352/1000, Total Reward: -9907.696556091309
# Episode 353/1000, Total Reward: -9906.8740234375
# Episode 354/1000, Total Reward: -9989.590812683105
# Episode 355/1000, Total Reward: -9871.750061035156
# Episode 356/1000, Total Reward: -9935.066036224365
# Episode 357/1000, Total Reward: 2751.0252799987793
# Episode 358/1000, Total Reward: 5133.210380554199
# Episode 359/1000, Total Reward: -9866.250358581543
# Episode 360/1000, Total Reward: -9838.933769226074
# Episode 361/1000, Total Reward: -9949.973415374756
# Episode 362/1000, Total Reward: -9955.080875396729
# Episode 363/1000, Total Reward: -9906.148685455322
# Episode 364/1000, Total Reward: -9808.395683288574
# Episode 365/1000, Total Reward: 5922.566307067871
# Episode 366/1000, Total Reward: -9895.990943908691
# Episode 367/1000, Total Reward: 1920.8302192687988
# Episode 368/1000, Total Reward: -9979.065811157227
# Episode 369/1000, Total Reward: -541.3650054931641
# Episode 370/1000, Total Reward: -9836.821487426758
# Episode 371/1000, Total Reward: -9937.026695251465
# Episode 372/1000, Total Reward: -9886.924308776855
# Episode 373/1000, Total Reward: -9969.283061981201
# Episode 374/1000, Total Reward: -9825.995040893555
# Episode 375/1000, Total Reward: 8768.991847991943
# Episode 376/1000, Total Reward: -9902.987113952637
# Episode 377/1000, Total Reward: -9936.574474334717
# Episode 378/1000, Total Reward: -9817.208587646484
# Episode 379/1000, Total Reward: 2591.6561279296875
# Episode 380/1000, Total Reward: -951.252025604248
# Episode 381/1000, Total Reward: 1348.2360229492188
# Episode 382/1000, Total Reward: 78.53304290771484
# Episode 383/1000, Total Reward: -1700.109977722168
# Episode 384/1000, Total Reward: 3133.592227935791
# Episode 385/1000, Total Reward: -144.94628524780273
# Episode 386/1000, Total Reward: 4003.084400177002
# Episode 387/1000, Total Reward: -1356.1577835083008
# Episode 388/1000, Total Reward: -237.7487335205078
# Episode 389/1000, Total Reward: -2820.951072692871
# Episode 390/1000, Total Reward: -1270.922264099121
# Episode 391/1000, Total Reward: -1172.3479690551758
# Episode 392/1000, Total Reward: 571.6391220092773
# Episode 393/1000, Total Reward: 721.0096015930176
# Episode 394/1000, Total Reward: -1809.725040435791
# Episode 395/1000, Total Reward: -34.75168991088867
# Episode 396/1000, Total Reward: 300.9656105041504
# Episode 397/1000, Total Reward: 40.131431579589844
# Episode 398/1000, Total Reward: 1784.4978103637695
# Episode 399/1000, Total Reward: -827.6862487792969
# Episode 400/1000, Total Reward: -1428.3016357421875
# Episode 401/1000, Total Reward: -87.64110565185547
# Episode 402/1000, Total Reward: 571.8957672119141
# Episode 403/1000, Total Reward: 296.44588470458984
# Episode 404/1000, Total Reward: 2522.8661918640137
# Episode 405/1000, Total Reward: -976.14013671875
# Episode 406/1000, Total Reward: 1579.7202987670898
# Episode 407/1000, Total Reward: 1179.4921760559082
# Episode 408/1000, Total Reward: 1913.7033309936523
# Episode 409/1000, Total Reward: 491.13286209106445
# Episode 410/1000, Total Reward: 515.1945724487305
# Episode 411/1000, Total Reward: 761.0300521850586
# Episode 412/1000, Total Reward: 1752.169334411621
# Episode 413/1000, Total Reward: 845.1037063598633
# Episode 414/1000, Total Reward: 1151.1308059692383
# Episode 415/1000, Total Reward: 682.0085945129395
# Episode 416/1000, Total Reward: -661.5152893066406
# Episode 417/1000, Total Reward: -547.2799530029297
# Episode 418/1000, Total Reward: -30.202796936035156
# Episode 419/1000, Total Reward: -9861.124313354492
# Episode 420/1000, Total Reward: 1278.054988861084
# Episode 421/1000, Total Reward: 538.9718856811523
# Episode 422/1000, Total Reward: -561.7486991882324
# Episode 423/1000, Total Reward: 2985.6311645507812
# Episode 424/1000, Total Reward: -870.0946807861328
# Episode 425/1000, Total Reward: 1773.8116149902344
# Episode 426/1000, Total Reward: 994.6426086425781
# Episode 427/1000, Total Reward: -0.9342803955078125
# Episode 428/1000, Total Reward: -1785.8390464782715
# Episode 429/1000, Total Reward: 2113.7941932678223
# Episode 430/1000, Total Reward: -989.4791946411133
# Episode 431/1000, Total Reward: 233.77112579345703
# Episode 432/1000, Total Reward: -183.02976989746094
# Episode 433/1000, Total Reward: -798.8138046264648
# Episode 434/1000, Total Reward: -9990.398643493652
# Episode 435/1000, Total Reward: 748.8577423095703
# Episode 436/1000, Total Reward: 2685.921340942383
# Episode 437/1000, Total Reward: -964.9644927978516
# Episode 438/1000, Total Reward: 18.94756317138672
# Episode 439/1000, Total Reward: 43.78041076660156
# Episode 440/1000, Total Reward: 2585.290870666504
# Episode 441/1000, Total Reward: -1159.0874099731445
# Episode 442/1000, Total Reward: 1730.1250839233398
# Episode 443/1000, Total Reward: -9865.920783996582
# Episode 444/1000, Total Reward: 3257.1092529296875
# Episode 445/1000, Total Reward: -2223.05961227417
# Episode 446/1000, Total Reward: -1566.3796691894531
# Episode 447/1000, Total Reward: 2972.338447570801
# Episode 448/1000, Total Reward: -1553.3203582763672
# Episode 449/1000, Total Reward: -588.157958984375
# Episode 450/1000, Total Reward: -418.9511489868164
# Episode 451/1000, Total Reward: -172.83197784423828
# Episode 452/1000, Total Reward: 1640.7855529785156
# Episode 453/1000, Total Reward: 775.0747299194336
# Episode 454/1000, Total Reward: -216.5952377319336
# Episode 455/1000, Total Reward: -525.8955688476562
# Episode 456/1000, Total Reward: -1743.0635719299316
# Episode 457/1000, Total Reward: -515.4609298706055
# Episode 458/1000, Total Reward: -633.1425361633301
# Episode 459/1000, Total Reward: 764.0691680908203
# Episode 460/1000, Total Reward: -620.3942031860352
# Episode 461/1000, Total Reward: -2149.5668716430664
# Episode 462/1000, Total Reward: 2211.450428009033
# Episode 463/1000, Total Reward: 671.7555770874023
# Episode 464/1000, Total Reward: -1907.8617706298828
# Episode 465/1000, Total Reward: 1638.3777618408203
# Episode 466/1000, Total Reward: 1363.248649597168
# Episode 467/1000, Total Reward: 1840.722541809082
# Episode 468/1000, Total Reward: -639.1912994384766
# Episode 469/1000, Total Reward: 268.8711624145508
# Episode 470/1000, Total Reward: 4240.400665283203
# Episode 471/1000, Total Reward: 1188.1950225830078
# Episode 472/1000, Total Reward: -1457.0440673828125
# Episode 473/1000, Total Reward: -918.3159027099609
# Episode 474/1000, Total Reward: 963.2427520751953
# Episode 475/1000, Total Reward: 1727.4728355407715
# Episode 476/1000, Total Reward: -9841.861099243164
# Episode 477/1000, Total Reward: 2055.326484680176
# Episode 478/1000, Total Reward: -108.4764633178711
# Episode 479/1000, Total Reward: -808.6666641235352
# Episode 480/1000, Total Reward: -291.3682098388672
# Episode 481/1000, Total Reward: -217.46732330322266
# Episode 482/1000, Total Reward: -1910.6143188476562
# Episode 483/1000, Total Reward: -373.57936096191406
# Episode 484/1000, Total Reward: 645.0382385253906
# Episode 485/1000, Total Reward: -831.7555389404297
# Episode 486/1000, Total Reward: 1520.8146286010742
# Episode 487/1000, Total Reward: -1698.8960189819336
# Episode 488/1000, Total Reward: 1132.0465698242188
# Episode 489/1000, Total Reward: 1176.3458633422852
# Episode 490/1000, Total Reward: -99.86562728881836
# Episode 491/1000, Total Reward: -810.9279251098633
# Episode 492/1000, Total Reward: -1123.5897598266602
# Episode 493/1000, Total Reward: 171.48504638671875
# Episode 494/1000, Total Reward: 918.942741394043
# Episode 495/1000, Total Reward: -254.16663360595703
# Episode 496/1000, Total Reward: -623.248779296875
# Episode 497/1000, Total Reward: -1431.8221855163574
# Episode 498/1000, Total Reward: 989.1971130371094
# Episode 499/1000, Total Reward: 1176.7245483398438
# Episode 500/1000, Total Reward: 862.4389572143555
# Episode 501/1000, Total Reward: -738.2874298095703
# Episode 502/1000, Total Reward: -1038.6355171203613
# Episode 503/1000, Total Reward: 1516.167869567871
# Episode 504/1000, Total Reward: 2100.420223236084
# Episode 505/1000, Total Reward: 596.0738906860352
# Episode 506/1000, Total Reward: -767.8819389343262
# Episode 507/1000, Total Reward: 930.7558212280273
# Episode 508/1000, Total Reward: 866.4240036010742
# Episode 509/1000, Total Reward: -2203.4568214416504
# Episode 510/1000, Total Reward: 1111.1793365478516
# Episode 511/1000, Total Reward: 1621.7372016906738
# Episode 512/1000, Total Reward: 851.5511016845703
# Episode 513/1000, Total Reward: 655.6635513305664
# Episode 514/1000, Total Reward: 589.6875686645508
# Episode 515/1000, Total Reward: -938.4433517456055
# Episode 516/1000, Total Reward: 486.54809188842773
# Episode 517/1000, Total Reward: 96.3255615234375
# Episode 518/1000, Total Reward: -1919.5371932983398
# Episode 519/1000, Total Reward: -376.0018539428711
# Episode 520/1000, Total Reward: 1999.3798866271973
# Episode 521/1000, Total Reward: -1339.9329681396484
# Episode 522/1000, Total Reward: -1814.9136199951172
# Episode 523/1000, Total Reward: -199.789306640625
# Episode 524/1000, Total Reward: -144.53006744384766
# Episode 525/1000, Total Reward: -378.66759490966797
# Episode 526/1000, Total Reward: 1982.4601516723633
# Episode 527/1000, Total Reward: 418.44700622558594
# Episode 528/1000, Total Reward: 1908.129093170166
# Episode 529/1000, Total Reward: -780.8602981567383
# Episode 530/1000, Total Reward: -1710.1464080810547
# Episode 531/1000, Total Reward: -739.2414474487305
# Episode 532/1000, Total Reward: -4025.0022926330566
# Episode 533/1000, Total Reward: 1792.0327110290527
# Episode 534/1000, Total Reward: 2543.3212280273438
# Episode 535/1000, Total Reward: 2715.0235595703125
# Episode 536/1000, Total Reward: 5135.551597595215
# Episode 537/1000, Total Reward: 2230.498489379883
# Episode 538/1000, Total Reward: 3247.3737030029297
# Episode 539/1000, Total Reward: -1218.9782333374023
# Episode 540/1000, Total Reward: -528.5444183349609
# Episode 541/1000, Total Reward: 946.1018447875977
# Episode 542/1000, Total Reward: 1342.904010772705
# Episode 543/1000, Total Reward: -284.0647506713867
# Episode 544/1000, Total Reward: 1262.9559631347656
# Episode 545/1000, Total Reward: -1754.0490646362305
# Episode 546/1000, Total Reward: 74.39115905761719
# Episode 547/1000, Total Reward: -2194.919891357422
# Episode 548/1000, Total Reward: -1735.25244140625
# Episode 549/1000, Total Reward: 2339.4021492004395
# Episode 550/1000, Total Reward: 505.3468322753906
# Episode 551/1000, Total Reward: 552.6642837524414
# Episode 552/1000, Total Reward: 629.83056640625
# Episode 553/1000, Total Reward: 977.7179412841797
# Episode 554/1000, Total Reward: -1476.1628036499023
# Episode 555/1000, Total Reward: 152.16606521606445
# Episode 556/1000, Total Reward: 687.0997734069824
# Episode 557/1000, Total Reward: -44.76731872558594
# Episode 558/1000, Total Reward: -393.4121322631836
# Episode 559/1000, Total Reward: 10048.842872619629
# Episode 560/1000, Total Reward: -402.3414764404297
# Episode 561/1000, Total Reward: -475.2664260864258
# Episode 562/1000, Total Reward: -9937.266941070557
# Episode 563/1000, Total Reward: -9998.39584350586
# Episode 564/1000, Total Reward: -1071.7032775878906
# Episode 565/1000, Total Reward: -9845.851364135742
# Episode 566/1000, Total Reward: -9822.471393585205
# Episode 567/1000, Total Reward: -1329.3497848510742
# Episode 568/1000, Total Reward: -9891.58920288086
# Episode 569/1000, Total Reward: -9872.695407867432
# Episode 570/1000, Total Reward: -9868.559513092041
# Episode 571/1000, Total Reward: 3588.4637184143066
# Episode 572/1000, Total Reward: -9873.405742645264
# Episode 573/1000, Total Reward: -9868.807800292969
# Episode 574/1000, Total Reward: 3164.5407791137695
# Episode 575/1000, Total Reward: 11163.977657318115
# Episode 576/1000, Total Reward: 4256.6267013549805
# Episode 577/1000, Total Reward: -9909.894393920898
# Episode 578/1000, Total Reward: -9910.721660614014
# Episode 579/1000, Total Reward: -9872.042659759521
# Episode 580/1000, Total Reward: 16096.713500976562
# Episode 581/1000, Total Reward: 3120.961799621582
# Episode 582/1000, Total Reward: 5925.729095458984
# Episode 583/1000, Total Reward: 6577.889854431152
# Episode 584/1000, Total Reward: 6446.717193603516
# Episode 585/1000, Total Reward: 20208.823944091797
# Episode 586/1000, Total Reward: -9881.164817810059
# Episode 587/1000, Total Reward: 7706.940780639648
# Episode 588/1000, Total Reward: 2097.483444213867
# Episode 589/1000, Total Reward: -9807.746574401855
# Episode 590/1000, Total Reward: 1261.1669387817383
# Episode 591/1000, Total Reward: -818.1439743041992
# Episode 592/1000, Total Reward: 5352.0369873046875
# Episode 593/1000, Total Reward: -9889.816749572754
# Episode 594/1000, Total Reward: -9997.657459259033
# Episode 595/1000, Total Reward: -9999.424179077148
# Episode 596/1000, Total Reward: -9996.849445343018
# Episode 597/1000, Total Reward: -9988.530410766602
# Episode 598/1000, Total Reward: -9991.326717376709
# Episode 599/1000, Total Reward: -9995.401416778564
# Episode 600/1000, Total Reward: -9999.026153564453
# Episode 601/1000, Total Reward: -9922.27674484253
# Episode 602/1000, Total Reward: -9995.968852996826
# Episode 603/1000, Total Reward: -9998.599697113037
# Episode 604/1000, Total Reward: -9964.331405639648
# Episode 605/1000, Total Reward: -9991.135696411133
# Episode 606/1000, Total Reward: -9849.805294036865
# Episode 607/1000, Total Reward: -9979.381214141846
# Episode 608/1000, Total Reward: -9896.72966003418
# Episode 609/1000, Total Reward: -9996.690349578857
# Episode 610/1000, Total Reward: -9977.640850067139
# Episode 611/1000, Total Reward: -9991.667503356934
# Episode 612/1000, Total Reward: -9985.652027130127
# Episode 613/1000, Total Reward: -9854.609851837158
# Episode 614/1000, Total Reward: -9996.631771087646
# Episode 615/1000, Total Reward: -9998.789249420166
# Episode 616/1000, Total Reward: -9999.534973144531
# Episode 617/1000, Total Reward: -9981.84843826294
# Episode 618/1000, Total Reward: -9990.725128173828
# Episode 619/1000, Total Reward: -9881.654697418213
# Episode 620/1000, Total Reward: -9856.175457000732
# Episode 621/1000, Total Reward: -9989.844020843506
# Episode 622/1000, Total Reward: -9988.258972167969
# Episode 623/1000, Total Reward: -9996.979511260986
# Episode 624/1000, Total Reward: -9980.70700454712
# Episode 625/1000, Total Reward: -9878.647201538086
# Episode 626/1000, Total Reward: -9835.648876190186
# Episode 627/1000, Total Reward: -9920.047245025635
# Episode 628/1000, Total Reward: -9798.069477081299
# Episode 629/1000, Total Reward: -9992.31247329712
# Episode 630/1000, Total Reward: -9938.47205734253
# Episode 631/1000, Total Reward: -9996.516494750977
# Episode 632/1000, Total Reward: -9995.237567901611
# Episode 633/1000, Total Reward: -9968.597415924072
# Episode 634/1000, Total Reward: -9989.697765350342
# Episode 635/1000, Total Reward: -9993.126319885254
# Episode 636/1000, Total Reward: -9984.140323638916
# Episode 637/1000, Total Reward: -9983.409091949463
# Episode 638/1000, Total Reward: -9990.016868591309
# Episode 639/1000, Total Reward: -9980.15076828003
# Episode 640/1000, Total Reward: -9983.72061920166
# Episode 641/1000, Total Reward: -9988.540088653564
# Episode 642/1000, Total Reward: -9994.589450836182
# Episode 643/1000, Total Reward: -9882.370918273926
# Episode 644/1000, Total Reward: -9876.629165649414
# Episode 645/1000, Total Reward: -9989.805660247803
# Episode 646/1000, Total Reward: -9996.761909484863
# Episode 647/1000, Total Reward: -9986.529796600342
# Episode 648/1000, Total Reward: -9974.85241317749
# Episode 649/1000, Total Reward: -9892.153282165527
# Episode 650/1000, Total Reward: -9999.605003356934
# Episode 651/1000, Total Reward: -9992.36107635498
# Episode 652/1000, Total Reward: -9997.643440246582
# Episode 653/1000, Total Reward: 61.68644332885742
# Episode 654/1000, Total Reward: -1417.2526092529297
# Episode 655/1000, Total Reward: 1751.5435028076172
# Episode 656/1000, Total Reward: -1010.3876724243164
# Episode 657/1000, Total Reward: -616.5508041381836
# Episode 658/1000, Total Reward: 52.162513732910156
# Episode 659/1000, Total Reward: 5614.408981323242
# Episode 660/1000, Total Reward: 24177.660762786865
# Episode 661/1000, Total Reward: -9942.032752990723
# Episode 662/1000, Total Reward: 5986.6418533325195
# Episode 663/1000, Total Reward: 2857.792304992676
# Episode 664/1000, Total Reward: -9912.301292419434
# Episode 665/1000, Total Reward: -9993.487342834473
# Episode 666/1000, Total Reward: -9824.33317565918
# Episode 667/1000, Total Reward: -9934.315689086914
# Episode 668/1000, Total Reward: 31784.34440612793
# Episode 669/1000, Total Reward: 3309.7151794433594
# Episode 670/1000, Total Reward: -9885.980278015137
# Episode 671/1000, Total Reward: 6163.6577224731445
# Episode 672/1000, Total Reward: -9939.897060394287
# Episode 673/1000, Total Reward: 4558.0113525390625
# Episode 674/1000, Total Reward: 2143.3460998535156
# Episode 675/1000, Total Reward: -9843.483383178711
# Episode 676/1000, Total Reward: 5102.314743041992
# Episode 677/1000, Total Reward: 1946.7926406860352
# Episode 678/1000, Total Reward: -9989.423782348633
# Episode 679/1000, Total Reward: -9923.386268615723
# Episode 680/1000, Total Reward: 1526.6445541381836
# Episode 681/1000, Total Reward: -9938.366065979004
# Episode 682/1000, Total Reward: -9983.016960144043
# Episode 683/1000, Total Reward: -9965.556678771973
# Episode 684/1000, Total Reward: -9986.000701904297
# Episode 685/1000, Total Reward: -9875.459945678711
# Episode 686/1000, Total Reward: -9992.54833984375
# Episode 687/1000, Total Reward: 12858.879333496094
# Episode 688/1000, Total Reward: 4323.401268005371
# Episode 689/1000, Total Reward: 22032.78092956543
# Episode 690/1000, Total Reward: 5159.4409103393555
# Episode 691/1000, Total Reward: -9876.237243652344
# Episode 692/1000, Total Reward: -9974.709327697754
# Episode 693/1000, Total Reward: -9962.6595993042
# Episode 694/1000, Total Reward: 969.3544998168945
# Episode 695/1000, Total Reward: 8960.112197875977
# Episode 696/1000, Total Reward: 987.1902542114258
# Episode 697/1000, Total Reward: -9809.284866333008
# Episode 698/1000, Total Reward: 12831.97779083252
# Episode 699/1000, Total Reward: -9919.959465026855
# Episode 700/1000, Total Reward: -9812.447479248047
# Episode 701/1000, Total Reward: 3703.613639831543
# Episode 702/1000, Total Reward: -9974.071376800537
# Episode 703/1000, Total Reward: -9954.647701263428
# Episode 704/1000, Total Reward: 1928.1904296875
# Episode 705/1000, Total Reward: -9879.607475280762
# Episode 706/1000, Total Reward: -9862.500503540039
# Episode 707/1000, Total Reward: 8841.413223266602
# Episode 708/1000, Total Reward: 150.1217041015625
# Episode 709/1000, Total Reward: -9853.319213867188
# Episode 710/1000, Total Reward: -9889.592086791992
# Episode 711/1000, Total Reward: -9883.840431213379
# Episode 712/1000, Total Reward: -9979.534797668457
# Episode 713/1000, Total Reward: 14722.135841369629
# Episode 714/1000, Total Reward: 8178.811828613281
# Episode 715/1000, Total Reward: 5147.697769165039
# Episode 716/1000, Total Reward: -9998.703636169434
# Episode 717/1000, Total Reward: 31011.046577453613
# Episode 718/1000, Total Reward: 4016.134593963623
# Episode 719/1000, Total Reward: -9971.069709777832
# Episode 720/1000, Total Reward: -359.9142150878906
# Episode 721/1000, Total Reward: -9854.017234802246
# Episode 722/1000, Total Reward: 34334.73433685303
# Episode 723/1000, Total Reward: -9835.819412231445
# Episode 724/1000, Total Reward: -9925.082313537598
# Episode 725/1000, Total Reward: -9888.214069366455
# Episode 726/1000, Total Reward: -9993.585216522217
# Episode 727/1000, Total Reward: -9999.35029220581
# Episode 728/1000, Total Reward: -9987.072742462158
# Episode 729/1000, Total Reward: -9994.660442352295
# Episode 730/1000, Total Reward: -9999.15442276001
# Episode 731/1000, Total Reward: -9997.13928604126
# Episode 732/1000, Total Reward: -9996.246467590332
# Episode 733/1000, Total Reward: -9992.563766479492
# Episode 734/1000, Total Reward: -9990.942890167236
# Episode 735/1000, Total Reward: -9995.30994796753
# Episode 736/1000, Total Reward: -9992.331951141357
# Episode 737/1000, Total Reward: -9996.981349945068
# Episode 738/1000, Total Reward: -9999.336112976074
# Episode 739/1000, Total Reward: -9997.607814788818
# Episode 740/1000, Total Reward: -9991.288776397705
# Episode 741/1000, Total Reward: -9983.433197021484
# Episode 742/1000, Total Reward: -9995.220161437988
# Episode 743/1000, Total Reward: -9882.345211029053
# Episode 744/1000, Total Reward: -9989.134357452393
# Episode 745/1000, Total Reward: -9914.137432098389
# Episode 746/1000, Total Reward: -9848.61653137207
# Episode 747/1000, Total Reward: 12199.571075439453
# Episode 748/1000, Total Reward: 17690.85252380371
# Episode 749/1000, Total Reward: -9881.216979980469
# Episode 750/1000, Total Reward: -9993.642307281494
# Episode 751/1000, Total Reward: -9993.858177185059
# Episode 752/1000, Total Reward: -9994.931777954102
# Episode 753/1000, Total Reward: -9999.187664031982
# Episode 754/1000, Total Reward: -9994.010330200195
# Episode 755/1000, Total Reward: -9992.201816558838
# Episode 756/1000, Total Reward: -9998.777103424072
# Episode 757/1000, Total Reward: -9999.03535079956
# Episode 758/1000, Total Reward: -9995.123332977295
# Episode 759/1000, Total Reward: -9892.281513214111
# Episode 760/1000, Total Reward: -9998.845836639404
# Episode 761/1000, Total Reward: -9908.671184539795
# Episode 762/1000, Total Reward: -9836.44436264038
# Episode 763/1000, Total Reward: -9991.780544281006
# Episode 764/1000, Total Reward: -9990.296329498291
# Episode 765/1000, Total Reward: -9999.910945892334
# Episode 766/1000, Total Reward: -9987.734577178955
# Episode 767/1000, Total Reward: -9997.42142868042
# Episode 768/1000, Total Reward: -9998.622959136963
# Episode 769/1000, Total Reward: -9993.709339141846
# Episode 770/1000, Total Reward: -9995.962078094482
# Episode 771/1000, Total Reward: -9995.77713394165
# Episode 772/1000, Total Reward: -9993.68949508667
# Episode 773/1000, Total Reward: -9995.547687530518
# Episode 774/1000, Total Reward: -9996.223690032959
# Episode 775/1000, Total Reward: -9993.945728302002
# Episode 776/1000, Total Reward: -9855.885807037354
# Episode 777/1000, Total Reward: -9906.520919799805
# Episode 778/1000, Total Reward: -9978.75548171997
# Episode 779/1000, Total Reward: -9997.684825897217
# Episode 780/1000, Total Reward: -9998.745136260986
# Episode 781/1000, Total Reward: -9995.07572555542
# Episode 782/1000, Total Reward: -9994.108142852783
# Episode 783/1000, Total Reward: -9992.913478851318
# Episode 784/1000, Total Reward: -9998.145942687988
# Episode 785/1000, Total Reward: -9838.889236450195
# Episode 786/1000, Total Reward: -9990.964450836182
# Episode 787/1000, Total Reward: -9997.511394500732
# Episode 788/1000, Total Reward: -9997.05456161499
# Episode 789/1000, Total Reward: -9999.57548904419
# Episode 790/1000, Total Reward: -9990.411693572998
# Episode 791/1000, Total Reward: -9997.210510253906
# Episode 792/1000, Total Reward: -9964.84806060791
# Episode 793/1000, Total Reward: -9997.805233001709
# Episode 794/1000, Total Reward: -9985.953037261963
# Episode 795/1000, Total Reward: -9996.800617218018
# Episode 796/1000, Total Reward: -9997.671443939209
# Episode 797/1000, Total Reward: -9998.39873123169
# Episode 798/1000, Total Reward: -9984.216041564941
# Episode 799/1000, Total Reward: -9999.796920776367
# Episode 800/1000, Total Reward: -9909.190937042236
# Episode 801/1000, Total Reward: -9992.457584381104
# Episode 802/1000, Total Reward: -9995.97896194458
# Episode 803/1000, Total Reward: -9999.357864379883
# Episode 804/1000, Total Reward: -9995.825969696045
# Episode 805/1000, Total Reward: -9994.914470672607
# Episode 806/1000, Total Reward: -9999.112674713135
# Episode 807/1000, Total Reward: -9995.955486297607
# Episode 808/1000, Total Reward: -9988.106243133545
# Episode 809/1000, Total Reward: -9995.689975738525
# Episode 810/1000, Total Reward: -9928.088996887207
# Episode 811/1000, Total Reward: -9998.991092681885
# Episode 812/1000, Total Reward: -9996.441341400146
# Episode 813/1000, Total Reward: -9992.372714996338
# Episode 814/1000, Total Reward: -9998.678279876709
# Episode 815/1000, Total Reward: -9996.772747039795
# Episode 816/1000, Total Reward: -9994.914249420166
# Episode 817/1000, Total Reward: -9997.761302947998
# Episode 818/1000, Total Reward: -9995.453159332275
# Episode 819/1000, Total Reward: -9997.67087173462
# Episode 820/1000, Total Reward: -9904.581069946289
# Episode 821/1000, Total Reward: -9997.761043548584
# Episode 822/1000, Total Reward: -9974.650375366211
# Episode 823/1000, Total Reward: -9999.636142730713
# Episode 824/1000, Total Reward: -9830.560199737549
# Episode 825/1000, Total Reward: -9998.299495697021
# Episode 826/1000, Total Reward: -9836.701347351074
# Episode 827/1000, Total Reward: -9997.340534210205
# Episode 828/1000, Total Reward: -9999.334865570068
# Episode 829/1000, Total Reward: -9906.93983078003
# Episode 830/1000, Total Reward: -9860.96530532837
# Episode 831/1000, Total Reward: -9995.567905426025
# Episode 832/1000, Total Reward: -9995.002113342285
# Episode 833/1000, Total Reward: -9986.158679962158
# Episode 834/1000, Total Reward: -9989.414203643799
# Episode 835/1000, Total Reward: -9996.026279449463
# Episode 836/1000, Total Reward: -9999.90871810913
# Episode 837/1000, Total Reward: -9994.529140472412
# Episode 838/1000, Total Reward: -9996.141147613525
# Episode 839/1000, Total Reward: -9994.840892791748
# Episode 840/1000, Total Reward: -9993.374774932861
# Episode 841/1000, Total Reward: -9996.10584640503
# Episode 842/1000, Total Reward: -9993.981819152832
# Episode 843/1000, Total Reward: -9997.91151046753
# Episode 844/1000, Total Reward: -9988.187900543213
# Episode 845/1000, Total Reward: -9865.831512451172
# Episode 846/1000, Total Reward: -9995.15822982788
# Episode 847/1000, Total Reward: -9994.959575653076
# Episode 848/1000, Total Reward: -9989.97700881958
# Episode 849/1000, Total Reward: -9988.717868804932
# Episode 850/1000, Total Reward: -9996.722190856934
# Episode 851/1000, Total Reward: -9998.915760040283
# Episode 852/1000, Total Reward: -9994.704349517822
# Episode 853/1000, Total Reward: -9999.469120025635
# Episode 854/1000, Total Reward: -9991.879665374756
# Episode 855/1000, Total Reward: -9994.150142669678
# Episode 856/1000, Total Reward: -9999.728984832764
# Episode 857/1000, Total Reward: -9996.958087921143
# Episode 858/1000, Total Reward: -9996.551147460938
# Episode 859/1000, Total Reward: -9992.489978790283
# Episode 860/1000, Total Reward: -9917.43314743042
# Episode 861/1000, Total Reward: -9993.963214874268
# Episode 862/1000, Total Reward: -9990.025981903076
# Episode 863/1000, Total Reward: -9999.360172271729
# Episode 864/1000, Total Reward: -9990.176258087158
# Episode 865/1000, Total Reward: -9992.200443267822
# Episode 866/1000, Total Reward: -9914.04076385498
# Episode 867/1000, Total Reward: -9999.380870819092
# Episode 868/1000, Total Reward: -9998.793277740479
# Episode 869/1000, Total Reward: -9999.534275054932
# Episode 870/1000, Total Reward: -9996.953983306885
# Episode 871/1000, Total Reward: -9992.45136642456
# Episode 872/1000, Total Reward: -9999.835582733154
# Episode 873/1000, Total Reward: -9903.839488983154
# Episode 874/1000, Total Reward: -9998.194011688232
# Episode 875/1000, Total Reward: -9998.460235595703
# Episode 876/1000, Total Reward: 4463.12451171875
# Episode 877/1000, Total Reward: 8009.62646484375
# Episode 878/1000, Total Reward: -9906.298141479492
# Episode 879/1000, Total Reward: -9918.843994140625
# Episode 880/1000, Total Reward: -1113.7821578979492
# Episode 881/1000, Total Reward: 526.0722808837891
# Episode 882/1000, Total Reward: -9893.538345336914
# Episode 883/1000, Total Reward: 7790.686920166016
# Episode 884/1000, Total Reward: -9915.244232177734
# Episode 885/1000, Total Reward: -9956.294723510742
# Episode 886/1000, Total Reward: 30786.358085632324
# Episode 887/1000, Total Reward: 8013.588394165039
# Episode 888/1000, Total Reward: -9967.821144104004
# Episode 889/1000, Total Reward: 3292.985305786133
# Episode 890/1000, Total Reward: -3180.01895904541
# Episode 891/1000, Total Reward: -9942.60954284668
# Episode 892/1000, Total Reward: 63.31773376464844
# Episode 893/1000, Total Reward: 8089.734504699707
# Episode 894/1000, Total Reward: -9831.697769165039
# Episode 895/1000, Total Reward: -9958.075241088867
# Episode 896/1000, Total Reward: -237.01324462890625
# Episode 897/1000, Total Reward: -550.7162094116211
# Episode 898/1000, Total Reward: -9796.31551361084
# Episode 899/1000, Total Reward: 3310.635917663574
# Episode 900/1000, Total Reward: 5006.578964233398
# Episode 901/1000, Total Reward: 1917.970703125
# Episode 902/1000, Total Reward: -9920.204414367676
# Episode 903/1000, Total Reward: -9933.945938110352
# Episode 904/1000, Total Reward: -9968.869346618652
# Episode 905/1000, Total Reward: 1774.9894790649414
# Episode 906/1000, Total Reward: 3644.6722717285156
# Episode 907/1000, Total Reward: 6025.622772216797
# Episode 908/1000, Total Reward: 132.8014373779297
# Episode 909/1000, Total Reward: -840.3778839111328
# Episode 910/1000, Total Reward: -9929.889511108398
# Episode 911/1000, Total Reward: 14295.24494934082
# Episode 912/1000, Total Reward: -9887.64958190918
# Episode 913/1000, Total Reward: -9964.267349243164
# Episode 914/1000, Total Reward: -9933.10693359375
# Episode 915/1000, Total Reward: 2487.2862091064453
# Episode 916/1000, Total Reward: -266.78346252441406
# Episode 917/1000, Total Reward: -9984.2509765625
# Episode 918/1000, Total Reward: -679.4293212890625
# Episode 919/1000, Total Reward: -9978.304870605469
# Episode 920/1000, Total Reward: 5998.591400146484
# Episode 921/1000, Total Reward: 752.7209014892578
# Episode 922/1000, Total Reward: -9999.393692016602
# Episode 923/1000, Total Reward: -1190.1354751586914
# Episode 924/1000, Total Reward: -9943.611511230469
# Episode 925/1000, Total Reward: 6422.4008712768555
# Episode 926/1000, Total Reward: -9942.766136169434
# Episode 927/1000, Total Reward: -9972.435684204102
# Episode 928/1000, Total Reward: 9740.91820526123
# Episode 929/1000, Total Reward: -9906.099739074707
# Episode 930/1000, Total Reward: -9919.862365722656
# Episode 931/1000, Total Reward: -9923.586288452148
# Episode 932/1000, Total Reward: 4415.195365905762
# Episode 933/1000, Total Reward: -9857.117309570312
# Episode 934/1000, Total Reward: 5982.327346801758
# Episode 935/1000, Total Reward: -2853.8535079956055
# Episode 936/1000, Total Reward: -9980.668128967285
# Episode 937/1000, Total Reward: 8566.602783203125
# Episode 938/1000, Total Reward: 1834.3366317749023
# Episode 939/1000, Total Reward: 3154.758041381836
# Episode 940/1000, Total Reward: -9886.142456054688
# Episode 941/1000, Total Reward: 7208.2551612854
# Episode 942/1000, Total Reward: 12671.548858642578
# Episode 943/1000, Total Reward: 18080.921447753906
# Episode 944/1000, Total Reward: -9996.853515625
# Episode 945/1000, Total Reward: -2278.9019165039062
# Episode 946/1000, Total Reward: -9862.71248626709
# Episode 947/1000, Total Reward: -9927.52896118164
# Episode 948/1000, Total Reward: 6113.592948913574
# Episode 949/1000, Total Reward: 637.5243835449219
# Episode 950/1000, Total Reward: -9982.175987243652
# Episode 951/1000, Total Reward: 2795.390579223633
# Episode 952/1000, Total Reward: -2434.4061279296875
# Episode 953/1000, Total Reward: -9979.591567993164
# Episode 954/1000, Total Reward: 3525.3931732177734
# Episode 955/1000, Total Reward: -1617.211166381836
# Episode 956/1000, Total Reward: -198.08468627929688
# Episode 957/1000, Total Reward: 2429.098129272461
# Episode 958/1000, Total Reward: -151.2909393310547
# Episode 959/1000, Total Reward: 431.9630126953125
# Episode 960/1000, Total Reward: 1499.268798828125
# Episode 961/1000, Total Reward: -41.45025634765625
# Episode 962/1000, Total Reward: 1619.278938293457
# Episode 963/1000, Total Reward: -174.03640747070312
# Episode 964/1000, Total Reward: -387.68750762939453
# Episode 965/1000, Total Reward: -9906.442855834961
# Episode 966/1000, Total Reward: 893.3389434814453
# Episode 967/1000, Total Reward: -297.158447265625
# Episode 968/1000, Total Reward: -9807.655883789062
# Episode 969/1000, Total Reward: -328.8552474975586
# Episode 970/1000, Total Reward: -952.137939453125
# Episode 971/1000, Total Reward: -9991.73310470581
# Episode 972/1000, Total Reward: -9998.190990447998
# Episode 973/1000, Total Reward: 13875.814304351807
# Episode 974/1000, Total Reward: -9882.547012329102
# Episode 975/1000, Total Reward: -9981.189353942871
# Episode 976/1000, Total Reward: 13342.63011932373
# Episode 977/1000, Total Reward: -9923.61905670166
# Episode 978/1000, Total Reward: -9832.061584472656
# Episode 979/1000, Total Reward: -9948.095184326172
# Episode 980/1000, Total Reward: -9908.300819396973
# Episode 981/1000, Total Reward: -9914.015251159668
# Episode 982/1000, Total Reward: -9871.109878540039
# Episode 983/1000, Total Reward: -9904.128845214844
# Episode 984/1000, Total Reward: 6763.724365234375
# Episode 985/1000, Total Reward: -9949.052490234375
# Episode 986/1000, Total Reward: 5075.895957946777
# Episode 987/1000, Total Reward: -9871.408088684082
# Episode 988/1000, Total Reward: -9895.312721252441
# Episode 989/1000, Total Reward: 11040.552429199219
# Episode 990/1000, Total Reward: -9872.684448242188
# Episode 991/1000, Total Reward: 4706.713607788086
# Episode 992/1000, Total Reward: -496.58349609375
# Episode 993/1000, Total Reward: -9995.317474365234
# Episode 994/1000, Total Reward: -9861.186660766602
# Episode 995/1000, Total Reward: 7368.195503234863
# Episode 996/1000, Total Reward: 9346.649688720703
# Episode 997/1000, Total Reward: 1574.5369720458984
# Episode 998/1000, Total Reward: 994.2645797729492
# Episode 999/1000, Total Reward: -9903.834732055664
# Episode 1000/1000, Total Reward: -9916.270706176758
# Training Complete!

# %%
# create a fresh environment instance for testing
test_env = TradingEnvironment(data)
state = test_env.reset()
done = False

# simulate a trading session using the trained agent
while not done:
    # always choose the best action (exploitation)
    action = agent.act(state)
    next_state, reward, done, _ = test_env.step(action)
    state = next_state if next_state is not None else state

final_balance = test_env.balance
profit = final_balance - test_env.initial_balance
print(f"Final Balance after testing: ${final_balance:.2f}")
print(f"Total Profit: ${profit:.2f}")
# Out:
# <ipython-input-6-3915787d8dfc>:4: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   float(data.loc[index, 'Close']),
# <ipython-input-6-3915787d8dfc>:5: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   float(data.loc[index, 'SMA_5']),
# <ipython-input-6-3915787d8dfc>:6: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   float(data.loc[index, 'SMA_20']),
# <ipython-input-6-3915787d8dfc>:7: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   float(data.loc[index, 'Returns'])
# <ipython-input-7-47ae0b5c48ca>:17: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   price = float(self.data.loc[self.index, 'Close']) # Get the current price (closing price)
# Final Balance after testing: $15127.47
# Total Profit: $5127.47
